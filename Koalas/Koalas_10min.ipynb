# %% [markdown]
# # 10 minutes to Koalas
#
# This is a short introduction to [Koalas](https://github.com/databricks/koalas), geared mainly for new users. This notebook shows you some key differences between pandas and Koalas.
#
# Customarily, we import Koalas as follows:

# %%
import pandas as pd
import numpy as np
import databricks.koalas as ks

import warnings
warnings.filterwarnings("ignore")  # Ignore warnings coming from Arrow optimizations
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Object Creation

# %% [markdown]
# Creating a Koalas Series by passing a list of values, letting Koalas create a default integer index:

# %%
s = ks.Series([1, 3, 5, np.nan, 6, 8])

s
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[92]: 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# Name: 0, dtype: float64</div>

# %%
type(s)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[93]: databricks.koalas.series.Series</div>

# %% [markdown]
# Creating a Koalas DataFrame by passing a dict of objects that can be converted to series-like.

# %%
kdf = ks.DataFrame(
    {'a': [1, 2, 3, 4, 5, 6],
     'b': [100, 200, 300, 400, 500, 600],
     'c': ["one", "two", "three", "four", "five", "six"]},
    index=[10, 20, 30, 40, 50, 60])

kdf
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a</th>
#       <th>b</th>
#       <th>c</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>10</th>
#       <td>1</td>
#       <td>100</td>
#       <td>one</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>2</td>
#       <td>200</td>
#       <td>two</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>3</td>
#       <td>300</td>
#       <td>three</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>4</td>
#       <td>400</td>
#       <td>four</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>5</td>
#       <td>500</td>
#       <td>five</td>
#     </tr>
#     <tr>
#       <th>60</th>
#       <td>6</td>
#       <td>600</td>
#       <td>six</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Creating a pandas DataFrame by passing a numpy array, with a datetime index and labeled columns:

# %%
dates = pd.date_range('20130101', periods=6)

dates
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[95]: DatetimeIndex([&#39;2013-01-01&#39;, &#39;2013-01-02&#39;, &#39;2013-01-03&#39;, &#39;2013-01-04&#39;,
#                &#39;2013-01-05&#39;, &#39;2013-01-06&#39;],
#               dtype=&#39;datetime64[ns]&#39;, freq=&#39;D&#39;)</div>

# %%
pdf = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list('ABCD'))

pdf
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2013-01-01</th>
#       <td>0.571412</td>
#       <td>1.130104</td>
#       <td>-1.047144</td>
#       <td>-0.994619</td>
#     </tr>
#     <tr>
#       <th>2013-01-02</th>
#       <td>0.160117</td>
#       <td>-0.003886</td>
#       <td>0.402744</td>
#       <td>-1.455676</td>
#     </tr>
#     <tr>
#       <th>2013-01-03</th>
#       <td>-1.491063</td>
#       <td>-1.240989</td>
#       <td>-0.396866</td>
#       <td>-0.875398</td>
#     </tr>
#     <tr>
#       <th>2013-01-04</th>
#       <td>-0.204507</td>
#       <td>-0.882168</td>
#       <td>0.206942</td>
#       <td>-0.365183</td>
#     </tr>
#     <tr>
#       <th>2013-01-05</th>
#       <td>-0.338535</td>
#       <td>-1.286701</td>
#       <td>1.109749</td>
#       <td>-1.514580</td>
#     </tr>
#     <tr>
#       <th>2013-01-06</th>
#       <td>0.046836</td>
#       <td>-0.586225</td>
#       <td>-1.734231</td>
#       <td>0.588693</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Now, this pandas DataFrame can be converted to a Koalas DataFrame

# %%
kdf = ks.from_pandas(pdf)

type(kdf)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[97]: databricks.koalas.frame.DataFrame</div>

# %% [markdown]
# It looks and behaves the same as a pandas DataFrame though

# %%
kdf
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2013-01-01</th>
#       <td>0.571412</td>
#       <td>1.130104</td>
#       <td>-1.047144</td>
#       <td>-0.994619</td>
#     </tr>
#     <tr>
#       <th>2013-01-02</th>
#       <td>0.160117</td>
#       <td>-0.003886</td>
#       <td>0.402744</td>
#       <td>-1.455676</td>
#     </tr>
#     <tr>
#       <th>2013-01-03</th>
#       <td>-1.491063</td>
#       <td>-1.240989</td>
#       <td>-0.396866</td>
#       <td>-0.875398</td>
#     </tr>
#     <tr>
#       <th>2013-01-04</th>
#       <td>-0.204507</td>
#       <td>-0.882168</td>
#       <td>0.206942</td>
#       <td>-0.365183</td>
#     </tr>
#     <tr>
#       <th>2013-01-05</th>
#       <td>-0.338535</td>
#       <td>-1.286701</td>
#       <td>1.109749</td>
#       <td>-1.514580</td>
#     </tr>
#     <tr>
#       <th>2013-01-06</th>
#       <td>0.046836</td>
#       <td>-0.586225</td>
#       <td>-1.734231</td>
#       <td>0.588693</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Also, it is possible to create a Koalas DataFrame from Spark DataFrame.
#
# Creating a Spark DataFrame from pandas DataFrame

# %%
sdf = spark.createDataFrame(pdf)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Creating Koalas DataFrame from Spark DataFrame.
# `to_koalas()` is automatically attached to Spark DataFrame and available as an API when Koalas is imported.

# %%
kdf = sdf.to_koalas()

kdf
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.571412</td>
#       <td>1.130104</td>
#       <td>-1.047144</td>
#       <td>-0.994619</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.160117</td>
#       <td>-0.003886</td>
#       <td>0.402744</td>
#       <td>-1.455676</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>-1.491063</td>
#       <td>-1.240989</td>
#       <td>-0.396866</td>
#       <td>-0.875398</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>-0.204507</td>
#       <td>-0.882168</td>
#       <td>0.206942</td>
#       <td>-0.365183</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>-0.338535</td>
#       <td>-1.286701</td>
#       <td>1.109749</td>
#       <td>-1.514580</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>0.046836</td>
#       <td>-0.586225</td>
#       <td>-1.734231</td>
#       <td>0.588693</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Having specific [dtypes](http://pandas.pydata.org/pandas-docs/stable/basics.html#basics-dtypes) . Types that are common to both Spark and pandas are currently supported.

# %%
print(kdf.dtypes)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">A    float64
# B    float64
# C    float64
# D    float64
# dtype: object
# </div>

# %% [markdown]
# ## Viewing Data
#
# See the [API Reference](https://koalas.readthedocs.io/en/latest/reference/index.html).

# %% [markdown]
# See the top rows of the frame. The results may not be the same as pandas though: unlike pandas, the data in a Spark dataframe is not _ordered_, it has no intrinsic notion of index. When asked for the head of a dataframe, Spark will just take the requested number of rows from a partition. Do not rely on it to return specific rows, use `.loc` or `iloc` instead.

# %%
kdf.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.571412</td>
#       <td>1.130104</td>
#       <td>-1.047144</td>
#       <td>-0.994619</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.160117</td>
#       <td>-0.003886</td>
#       <td>0.402744</td>
#       <td>-1.455676</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>-1.491063</td>
#       <td>-1.240989</td>
#       <td>-0.396866</td>
#       <td>-0.875398</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>-0.204507</td>
#       <td>-0.882168</td>
#       <td>0.206942</td>
#       <td>-0.365183</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>-0.338535</td>
#       <td>-1.286701</td>
#       <td>1.109749</td>
#       <td>-1.514580</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Display the index, columns, and the underlying numpy data.
#
# You can also retrieve the index; the index column can be ascribed to a DataFrame, see later

# %%
kdf.index
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[103]: Int64Index([0, 1, 2, 3, 4, 5], dtype=&#39;int64&#39;)</div>

# %%
kdf.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[104]: Index([&#39;A&#39;, &#39;B&#39;, &#39;C&#39;, &#39;D&#39;], dtype=&#39;object&#39;)</div>

# %%
kdf.to_numpy()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[105]: array([[ 0.57141186,  1.13010389, -1.04714405, -0.99461942],
#        [ 0.16011747, -0.00388586,  0.40274404, -1.45567588],
#        [-1.49106267, -1.24098946, -0.39686618, -0.8753977 ],
#        [-0.2045072 , -0.88216782,  0.20694223, -0.36518282],
#        [-0.33853482, -1.28670124,  1.10974858, -1.51458003],
#        [ 0.04683592, -0.58622493, -1.73423124,  0.58869254]])</div>

# %% [markdown]
# Describe shows a quick statistic summary of your data

# %%
kdf.describe()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>6.000000</td>
#       <td>6.000000</td>
#       <td>6.000000</td>
#       <td>6.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>-0.209290</td>
#       <td>-0.478311</td>
#       <td>-0.243134</td>
#       <td>-0.769461</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>0.703026</td>
#       <td>0.918912</td>
#       <td>1.033775</td>
#       <td>0.786897</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>-1.491063</td>
#       <td>-1.286701</td>
#       <td>-1.734231</td>
#       <td>-1.514580</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>-0.338535</td>
#       <td>-1.240989</td>
#       <td>-1.047144</td>
#       <td>-1.455676</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>-0.204507</td>
#       <td>-0.882168</td>
#       <td>-0.396866</td>
#       <td>-0.994619</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>0.160117</td>
#       <td>-0.003886</td>
#       <td>0.402744</td>
#       <td>-0.365183</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>0.571412</td>
#       <td>1.130104</td>
#       <td>1.109749</td>
#       <td>0.588693</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Transposing your data

# %%
kdf.T
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>A</th>
#       <td>0.571412</td>
#       <td>0.160117</td>
#       <td>-1.491063</td>
#       <td>-0.204507</td>
#       <td>-0.338535</td>
#       <td>0.046836</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>1.130104</td>
#       <td>-0.003886</td>
#       <td>-1.240989</td>
#       <td>-0.882168</td>
#       <td>-1.286701</td>
#       <td>-0.586225</td>
#     </tr>
#     <tr>
#       <th>C</th>
#       <td>-1.047144</td>
#       <td>0.402744</td>
#       <td>-0.396866</td>
#       <td>0.206942</td>
#       <td>1.109749</td>
#       <td>-1.734231</td>
#     </tr>
#     <tr>
#       <th>D</th>
#       <td>-0.994619</td>
#       <td>-1.455676</td>
#       <td>-0.875398</td>
#       <td>-0.365183</td>
#       <td>-1.514580</td>
#       <td>0.588693</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Sorting by its index

# %%
kdf.sort_index(ascending=False)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>5</th>
#       <td>0.046836</td>
#       <td>-0.586225</td>
#       <td>-1.734231</td>
#       <td>0.588693</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>-0.338535</td>
#       <td>-1.286701</td>
#       <td>1.109749</td>
#       <td>-1.514580</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>-0.204507</td>
#       <td>-0.882168</td>
#       <td>0.206942</td>
#       <td>-0.365183</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>-1.491063</td>
#       <td>-1.240989</td>
#       <td>-0.396866</td>
#       <td>-0.875398</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.160117</td>
#       <td>-0.003886</td>
#       <td>0.402744</td>
#       <td>-1.455676</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>0.571412</td>
#       <td>1.130104</td>
#       <td>-1.047144</td>
#       <td>-0.994619</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Sorting by value

# %%
kdf.sort_values(by='B')
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>4</th>
#       <td>-0.338535</td>
#       <td>-1.286701</td>
#       <td>1.109749</td>
#       <td>-1.514580</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>-1.491063</td>
#       <td>-1.240989</td>
#       <td>-0.396866</td>
#       <td>-0.875398</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>-0.204507</td>
#       <td>-0.882168</td>
#       <td>0.206942</td>
#       <td>-0.365183</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>0.046836</td>
#       <td>-0.586225</td>
#       <td>-1.734231</td>
#       <td>0.588693</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.160117</td>
#       <td>-0.003886</td>
#       <td>0.402744</td>
#       <td>-1.455676</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>0.571412</td>
#       <td>1.130104</td>
#       <td>-1.047144</td>
#       <td>-0.994619</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ## Missing Data
# Koalas primarily uses the value `np.nan` to represent missing data. It is by default not included in computations.

# %%
pdf1 = pdf.reindex(index=dates[0:4], columns=list(pdf.columns) + ['E'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
pdf1.loc[dates[0]:dates[1], 'E'] = 1
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
kdf1 = ks.from_pandas(pdf1)

kdf1
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#       <th>E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2013-01-01</th>
#       <td>0.571412</td>
#       <td>1.130104</td>
#       <td>-1.047144</td>
#       <td>-0.994619</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>2013-01-02</th>
#       <td>0.160117</td>
#       <td>-0.003886</td>
#       <td>0.402744</td>
#       <td>-1.455676</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>2013-01-03</th>
#       <td>-1.491063</td>
#       <td>-1.240989</td>
#       <td>-0.396866</td>
#       <td>-0.875398</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2013-01-04</th>
#       <td>-0.204507</td>
#       <td>-0.882168</td>
#       <td>0.206942</td>
#       <td>-0.365183</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# To drop any rows that have missing data.

# %%
kdf1.dropna(how='any')
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#       <th>E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2013-01-01</th>
#       <td>0.571412</td>
#       <td>1.130104</td>
#       <td>-1.047144</td>
#       <td>-0.994619</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>2013-01-02</th>
#       <td>0.160117</td>
#       <td>-0.003886</td>
#       <td>0.402744</td>
#       <td>-1.455676</td>
#       <td>1.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Filling missing data.

# %%
kdf1.fillna(value=5)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#       <th>E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2013-01-01</th>
#       <td>0.571412</td>
#       <td>1.130104</td>
#       <td>-1.047144</td>
#       <td>-0.994619</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>2013-01-02</th>
#       <td>0.160117</td>
#       <td>-0.003886</td>
#       <td>0.402744</td>
#       <td>-1.455676</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>2013-01-03</th>
#       <td>-1.491063</td>
#       <td>-1.240989</td>
#       <td>-0.396866</td>
#       <td>-0.875398</td>
#       <td>5.0</td>
#     </tr>
#     <tr>
#       <th>2013-01-04</th>
#       <td>-0.204507</td>
#       <td>-0.882168</td>
#       <td>0.206942</td>
#       <td>-0.365183</td>
#       <td>5.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ## Operations

# %% [markdown]
# ### Stats
# Operations in general exclude missing data.
#
# Performing a descriptive statistic:

# %%
print(kdf.mean())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">A   -0.209290
# B   -0.478311
# C   -0.243134
# D   -0.769461
# Name: 0, dtype: float64
# </div>

# %% [markdown]
# ### Spark Configurations
#
# Various configurations in PySpark could be applied internally in Koalas.
# For example, you can enable Arrow optimization to hugely speed up internal pandas conversion. See <a href="https://spark.apache.org/docs/latest/sql-pyspark-pandas-with-arrow.html">PySpark Usage Guide for Pandas with Apache Arrow</a>.

# %%
prev = spark.conf.get("spark.sql.execution.arrow.enabled")  # Keep its default value.
ks.set_option("compute.default_index_type", "distributed")  # Use default index prevent overhead.
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
spark.conf.set("spark.sql.execution.arrow.enabled", True)
# %timeit ks.range(300000).to_pandas()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">110 ms ± 6.18 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# </div>

# %%
spark.conf.set("spark.sql.execution.arrow.enabled", False)
# %timeit ks.range(300000).to_pandas()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">978 ms ± 29.8 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# </div>

# %%
ks.reset_option("compute.default_index_type")
spark.conf.set("spark.sql.execution.arrow.enabled", prev)  # Set its default value back.
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Grouping
# By “group by” we are referring to a process involving one or more of the following steps:
#
# - Splitting the data into groups based on some criteria
# - Applying a function to each group independently
# - Combining the results into a data structure

# %%
kdf = ks.DataFrame({'A': ['foo', 'bar', 'foo', 'bar',
                          'foo', 'bar', 'foo', 'foo'],
                    'B': ['one', 'one', 'two', 'three',
                          'two', 'two', 'one', 'three'],
                    'C': np.random.randn(8),
                    'D': np.random.randn(8)})

kdf
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>foo</td>
#       <td>one</td>
#       <td>0.896043</td>
#       <td>0.508333</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>bar</td>
#       <td>one</td>
#       <td>-0.933421</td>
#       <td>0.413316</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>foo</td>
#       <td>two</td>
#       <td>-1.489860</td>
#       <td>1.345921</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>bar</td>
#       <td>three</td>
#       <td>-0.362581</td>
#       <td>0.115927</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>foo</td>
#       <td>two</td>
#       <td>-0.921594</td>
#       <td>0.334012</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>bar</td>
#       <td>two</td>
#       <td>0.156917</td>
#       <td>2.019296</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>foo</td>
#       <td>one</td>
#       <td>-0.232733</td>
#       <td>0.308869</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>foo</td>
#       <td>three</td>
#       <td>0.251413</td>
#       <td>0.842143</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Grouping and then applying the [sum()](https://koalas.readthedocs.io/en/latest/reference/api/databricks.koalas.groupby.GroupBy.sum.html#databricks.koalas.groupby.GroupBy.sum) function to the resulting groups.

# %%
kdf.groupby('A').sum()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#     <tr>
#       <th>A</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>bar</th>
#       <td>-1.139086</td>
#       <td>2.548540</td>
#     </tr>
#     <tr>
#       <th>foo</th>
#       <td>-1.496731</td>
#       <td>3.339278</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Grouping by multiple columns forms a hierarchical index, and again we can apply the sum function.

# %%
kdf.groupby(['A', 'B']).sum()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#     <tr>
#       <th>A</th>
#       <th>B</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">foo</th>
#       <th>one</th>
#       <td>0.663310</td>
#       <td>0.817202</td>
#     </tr>
#     <tr>
#       <th>two</th>
#       <td>-2.411454</td>
#       <td>1.679932</td>
#     </tr>
#     <tr>
#       <th>bar</th>
#       <th>three</th>
#       <td>-0.362581</td>
#       <td>0.115927</td>
#     </tr>
#     <tr>
#       <th>foo</th>
#       <th>three</th>
#       <td>0.251413</td>
#       <td>0.842143</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">bar</th>
#       <th>two</th>
#       <td>0.156917</td>
#       <td>2.019296</td>
#     </tr>
#     <tr>
#       <th>one</th>
#       <td>-0.933421</td>
#       <td>0.413316</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ## Plotting
# See the <a href="https://koalas.readthedocs.io/en/latest/reference/frame.html#plotting">Plotting</a> docs.

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# On a DataFrame, the <a href="https://koalas.readthedocs.io/en/latest/reference/api/databricks.koalas.frame.DataFrame.plot.html#databricks.koalas.frame.DataFrame.plot">plot()</a> method is a convenience to plot all of the columns with labels:

# %%
pdf = pd.DataFrame(np.random.randn(1000, 4),
                   columns=['A', 'B', 'C', 'D'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
kdf = ks.from_pandas(pdf)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
cumsum = kdf.cumsum()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
cumsum.plot()

# %% [markdown]
# ## Getting data in/out
# See the <a href="https://koalas.readthedocs.io/en/latest/reference/io.html">Input/Output
# </a> docs.

# %% [markdown]
# ### CSV
#
# CSV is straightforward and easy to use. See <a href="https://koalas.readthedocs.io/en/latest/reference/api/databricks.koalas.DataFrame.to_csv.html#databricks.koalas.DataFrame.to_csv">here</a> to write a CSV file and <a href="https://koalas.readthedocs.io/en/latest/reference/api/databricks.koalas.read_csv.html#databricks.koalas.read_csv">here</a> to read a CSV file.

# %%
kdf.to_csv('foo.csv')
ks.read_csv('foo.csv').head(10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.693516</td>
#       <td>1.119301</td>
#       <td>-0.044440</td>
#       <td>-0.500197</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.833401</td>
#       <td>-1.935379</td>
#       <td>-0.796136</td>
#       <td>-1.862306</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>-0.680454</td>
#       <td>1.379520</td>
#       <td>-1.151356</td>
#       <td>0.863208</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>-1.443190</td>
#       <td>-1.580401</td>
#       <td>0.667405</td>
#       <td>-0.060056</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>-0.303501</td>
#       <td>-0.593678</td>
#       <td>-0.370050</td>
#       <td>-0.204131</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>0.464784</td>
#       <td>0.230441</td>
#       <td>-0.726708</td>
#       <td>-0.873669</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>-0.167640</td>
#       <td>1.075956</td>
#       <td>-1.087585</td>
#       <td>-0.794177</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>0.657539</td>
#       <td>-0.563552</td>
#       <td>0.982046</td>
#       <td>0.079383</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>1.866576</td>
#       <td>1.958371</td>
#       <td>-0.749136</td>
#       <td>1.085927</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>-0.681058</td>
#       <td>-0.113137</td>
#       <td>-0.671258</td>
#       <td>-0.377910</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### Parquet
#
# Parquet is an efficient and compact file format to read and write faster. See <a href="https://koalas.readthedocs.io/en/latest/reference/api/databricks.koalas.DataFrame.to_parquet.html#databricks.koalas.DataFrame.to_parquet">here</a> to write a Parquet file and <a href="https://koalas.readthedocs.io/en/latest/reference/api/databricks.koalas.read_parquet.html#databricks.koalas.read_parquet">here</a> to read a Parquet file.

# %%
kdf.to_parquet('bar.parquet')
ks.read_parquet('bar.parquet').head(10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.406628</td>
#       <td>1.226314</td>
#       <td>0.701700</td>
#       <td>0.213339</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>-0.504778</td>
#       <td>-0.742683</td>
#       <td>-2.400714</td>
#       <td>1.302415</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>-0.239768</td>
#       <td>0.750750</td>
#       <td>0.406187</td>
#       <td>-1.014281</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>-0.942408</td>
#       <td>-1.773379</td>
#       <td>-1.726570</td>
#       <td>-1.430995</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>-0.421397</td>
#       <td>-1.305309</td>
#       <td>-1.845884</td>
#       <td>0.189157</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>1.226664</td>
#       <td>-1.383740</td>
#       <td>-2.150283</td>
#       <td>0.249228</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>-1.225665</td>
#       <td>-1.858122</td>
#       <td>0.356379</td>
#       <td>0.087774</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>-1.071804</td>
#       <td>0.689514</td>
#       <td>0.222678</td>
#       <td>1.379892</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>-0.868509</td>
#       <td>0.026130</td>
#       <td>-0.376530</td>
#       <td>-0.789555</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>-0.986906</td>
#       <td>0.544499</td>
#       <td>-1.192561</td>
#       <td>-0.776510</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### Spark IO
#
# In addition, Koalas fully support Spark's various datasources such as ORC and an external datasource.  See <a href="https://koalas.readthedocs.io/en/latest/reference/api/databricks.koalas.DataFrame.to_spark_io.html#databricks.koalas.DataFrame.to_spark_io">here</a> to write it to the specified datasource and <a href="https://koalas.readthedocs.io/en/latest/reference/api/databricks.koalas.read_spark_io.html#databricks.koalas.read_spark_io">here</a> to read it from the datasource.

# %%
kdf.to_spark_io('zoo.orc', format="orc")
ks.read_spark_io('zoo.orc', format="orc").head(10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.693516</td>
#       <td>1.119301</td>
#       <td>-0.044440</td>
#       <td>-0.500197</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.833401</td>
#       <td>-1.935379</td>
#       <td>-0.796136</td>
#       <td>-1.862306</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>-0.680454</td>
#       <td>1.379520</td>
#       <td>-1.151356</td>
#       <td>0.863208</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>-1.443190</td>
#       <td>-1.580401</td>
#       <td>0.667405</td>
#       <td>-0.060056</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>-0.303501</td>
#       <td>-0.593678</td>
#       <td>-0.370050</td>
#       <td>-0.204131</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>0.464784</td>
#       <td>0.230441</td>
#       <td>-0.726708</td>
#       <td>-0.873669</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>-0.167640</td>
#       <td>1.075956</td>
#       <td>-1.087585</td>
#       <td>-0.794177</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>0.657539</td>
#       <td>-0.563552</td>
#       <td>0.982046</td>
#       <td>0.079383</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>1.866576</td>
#       <td>1.958371</td>
#       <td>-0.749136</td>
#       <td>1.085927</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>-0.681058</td>
#       <td>-0.113137</td>
#       <td>-0.671258</td>
#       <td>-0.377910</td>
#     </tr>
#   </tbody>
# </table>
# </div>
