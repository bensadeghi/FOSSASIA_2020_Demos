# %% [markdown]
# # 10 minutes to Koalas
#
# This is a short introduction to [Koalas](https://github.com/databricks/koalas), geared mainly for new users. This notebook shows you some key differences between pandas and Koalas.
#
# Customarily, we import Koalas as follows:

# %%
import pandas as pd
import numpy as np
import databricks.koalas as ks

import warnings
warnings.filterwarnings("ignore")  # Ignore warnings coming from Arrow optimizations
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Object Creation

# %% [markdown]
# Creating a Koalas Series by passing a list of values, letting Koalas create a default integer index:

# %%
s = ks.Series([1, 3, 5, np.nan, 6, 8])

s
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[42]: 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# Name: 0, dtype: float64</div>

# %%
type(s)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[43]: databricks.koalas.series.Series</div>

# %% [markdown]
# Creating a Koalas DataFrame by passing a dict of objects that can be converted to series-like.

# %%
kdf = ks.DataFrame(
    {'a': [1, 2, 3, 4, 5, 6],
     'b': [100, 200, 300, 400, 500, 600],
     'c': ["one", "two", "three", "four", "five", "six"]},
    index=[10, 20, 30, 40, 50, 60])

kdf
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a</th>
#       <th>b</th>
#       <th>c</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>10</th>
#       <td>1</td>
#       <td>100</td>
#       <td>one</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>2</td>
#       <td>200</td>
#       <td>two</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>3</td>
#       <td>300</td>
#       <td>three</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>4</td>
#       <td>400</td>
#       <td>four</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>5</td>
#       <td>500</td>
#       <td>five</td>
#     </tr>
#     <tr>
#       <th>60</th>
#       <td>6</td>
#       <td>600</td>
#       <td>six</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Creating a pandas DataFrame by passing a numpy array, with a datetime index and labeled columns:

# %%
dates = pd.date_range('20130101', periods=6)

dates
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[45]: DatetimeIndex([&#39;2013-01-01&#39;, &#39;2013-01-02&#39;, &#39;2013-01-03&#39;, &#39;2013-01-04&#39;,
#                &#39;2013-01-05&#39;, &#39;2013-01-06&#39;],
#               dtype=&#39;datetime64[ns]&#39;, freq=&#39;D&#39;)</div>

# %%
pdf = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list('ABCD'))

pdf
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2013-01-01</th>
#       <td>-0.226162</td>
#       <td>1.674793</td>
#       <td>-0.854056</td>
#       <td>1.022752</td>
#     </tr>
#     <tr>
#       <th>2013-01-02</th>
#       <td>0.206535</td>
#       <td>0.287895</td>
#       <td>0.541482</td>
#       <td>-0.859061</td>
#     </tr>
#     <tr>
#       <th>2013-01-03</th>
#       <td>-0.195844</td>
#       <td>-0.289040</td>
#       <td>-0.434537</td>
#       <td>-0.547957</td>
#     </tr>
#     <tr>
#       <th>2013-01-04</th>
#       <td>1.478943</td>
#       <td>-0.820070</td>
#       <td>0.641087</td>
#       <td>0.154080</td>
#     </tr>
#     <tr>
#       <th>2013-01-05</th>
#       <td>1.971336</td>
#       <td>0.735354</td>
#       <td>0.717406</td>
#       <td>0.549194</td>
#     </tr>
#     <tr>
#       <th>2013-01-06</th>
#       <td>2.584431</td>
#       <td>-0.119188</td>
#       <td>2.043724</td>
#       <td>-0.825224</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Now, this pandas DataFrame can be converted to a Koalas DataFrame

# %%
kdf = ks.from_pandas(pdf)

type(kdf)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[47]: databricks.koalas.frame.DataFrame</div>

# %% [markdown]
# It looks and behaves the same as a pandas DataFrame though

# %%
kdf
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2013-01-01</th>
#       <td>-0.226162</td>
#       <td>1.674793</td>
#       <td>-0.854056</td>
#       <td>1.022752</td>
#     </tr>
#     <tr>
#       <th>2013-01-02</th>
#       <td>0.206535</td>
#       <td>0.287895</td>
#       <td>0.541482</td>
#       <td>-0.859061</td>
#     </tr>
#     <tr>
#       <th>2013-01-03</th>
#       <td>-0.195844</td>
#       <td>-0.289040</td>
#       <td>-0.434537</td>
#       <td>-0.547957</td>
#     </tr>
#     <tr>
#       <th>2013-01-04</th>
#       <td>1.478943</td>
#       <td>-0.820070</td>
#       <td>0.641087</td>
#       <td>0.154080</td>
#     </tr>
#     <tr>
#       <th>2013-01-05</th>
#       <td>1.971336</td>
#       <td>0.735354</td>
#       <td>0.717406</td>
#       <td>0.549194</td>
#     </tr>
#     <tr>
#       <th>2013-01-06</th>
#       <td>2.584431</td>
#       <td>-0.119188</td>
#       <td>2.043724</td>
#       <td>-0.825224</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Also, it is possible to create a Koalas DataFrame from Spark DataFrame.
#
# Creating a Spark DataFrame from pandas DataFrame

# %%
sdf = spark.createDataFrame(pdf)

display(sdf)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>A</th><th>B</th><th>C</th><th>D</th></tr></thead><tbody><tr><td>-0.22616150996637382</td><td>1.674793217690699</td><td>-0.8540562429250863</td><td>1.0227517007159157</td></tr><tr><td>0.20653521432718347</td><td>0.2878952378271717</td><td>0.541481901992384</td><td>-0.8590614086302373</td></tr><tr><td>-0.19584432390161008</td><td>-0.2890397876684686</td><td>-0.43453683867519005</td><td>-0.5479565029008695</td></tr><tr><td>1.4789433136283276</td><td>-0.8200704440972859</td><td>0.6410874379685658</td><td>0.1540804853353233</td></tr><tr><td>1.971335976108796</td><td>0.735354276539254</td><td>0.7174059238777374</td><td>0.5491938744166764</td></tr><tr><td>2.584430810585542</td><td>-0.11918768672735852</td><td>2.0437243239415652</td><td>-0.8252243589777514</td></tr></tbody></table></div>

# %% [markdown]
# Creating Koalas DataFrame from Spark DataFrame.
# `to_koalas()` is automatically attached to Spark DataFrame and available as an API when Koalas is imported.

# %%
kdf = sdf.to_koalas()

kdf
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>-0.226162</td>
#       <td>1.674793</td>
#       <td>-0.854056</td>
#       <td>1.022752</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.206535</td>
#       <td>0.287895</td>
#       <td>0.541482</td>
#       <td>-0.859061</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>-0.195844</td>
#       <td>-0.289040</td>
#       <td>-0.434537</td>
#       <td>-0.547957</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1.478943</td>
#       <td>-0.820070</td>
#       <td>0.641087</td>
#       <td>0.154080</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1.971336</td>
#       <td>0.735354</td>
#       <td>0.717406</td>
#       <td>0.549194</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>2.584431</td>
#       <td>-0.119188</td>
#       <td>2.043724</td>
#       <td>-0.825224</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Having specific [dtypes](http://pandas.pydata.org/pandas-docs/stable/basics.html#basics-dtypes) . Types that are common to both Spark and pandas are currently supported.

# %%
print(kdf.dtypes)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">A    float64
# B    float64
# C    float64
# D    float64
# dtype: object
# </div>

# %% [markdown]
# ## Viewing Data
#
# See the [API Reference](https://koalas.readthedocs.io/en/latest/reference/index.html).

# %% [markdown]
# See the top rows of the frame. The results may not be the same as pandas though: unlike pandas, the data in a Spark dataframe is not _ordered_, it has no intrinsic notion of index. When asked for the head of a dataframe, Spark will just take the requested number of rows from a partition. Do not rely on it to return specific rows, use `.loc` or `iloc` instead.

# %%
kdf.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>-0.226162</td>
#       <td>1.674793</td>
#       <td>-0.854056</td>
#       <td>1.022752</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.206535</td>
#       <td>0.287895</td>
#       <td>0.541482</td>
#       <td>-0.859061</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>-0.195844</td>
#       <td>-0.289040</td>
#       <td>-0.434537</td>
#       <td>-0.547957</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1.478943</td>
#       <td>-0.820070</td>
#       <td>0.641087</td>
#       <td>0.154080</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1.971336</td>
#       <td>0.735354</td>
#       <td>0.717406</td>
#       <td>0.549194</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Display the index, columns, and the underlying numpy data.
#
# You can also retrieve the index; the index column can be ascribed to a DataFrame, see later

# %%
kdf.index
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[53]: Int64Index([0, 1, 2, 3, 4, 5], dtype=&#39;int64&#39;)</div>

# %%
kdf.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[54]: Index([&#39;A&#39;, &#39;B&#39;, &#39;C&#39;, &#39;D&#39;], dtype=&#39;object&#39;)</div>

# %%
kdf.to_numpy()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[55]: array([[-0.22616151,  1.67479322, -0.85405624,  1.0227517 ],
#        [ 0.20653521,  0.28789524,  0.5414819 , -0.85906141],
#        [-0.19584432, -0.28903979, -0.43453684, -0.5479565 ],
#        [ 1.47894331, -0.82007044,  0.64108744,  0.15408049],
#        [ 1.97133598,  0.73535428,  0.71740592,  0.54919387],
#        [ 2.58443081, -0.11918769,  2.04372432, -0.82522436]])</div>

# %% [markdown]
# Describe shows a quick statistic summary of your data

# %%
kdf.describe()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>6.000000</td>
#       <td>6.000000</td>
#       <td>6.000000</td>
#       <td>6.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>0.969873</td>
#       <td>0.244957</td>
#       <td>0.442518</td>
#       <td>-0.084369</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>1.203408</td>
#       <td>0.876219</td>
#       <td>1.013803</td>
#       <td>0.780757</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>-0.226162</td>
#       <td>-0.820070</td>
#       <td>-0.854056</td>
#       <td>-0.859061</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>-0.195844</td>
#       <td>-0.289040</td>
#       <td>-0.434537</td>
#       <td>-0.825224</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>0.206535</td>
#       <td>-0.119188</td>
#       <td>0.541482</td>
#       <td>-0.547957</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>1.971336</td>
#       <td>0.735354</td>
#       <td>0.717406</td>
#       <td>0.549194</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>2.584431</td>
#       <td>1.674793</td>
#       <td>2.043724</td>
#       <td>1.022752</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Transposing your data

# %%
kdf.T
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>A</th>
#       <td>-0.226162</td>
#       <td>0.206535</td>
#       <td>-0.195844</td>
#       <td>1.478943</td>
#       <td>1.971336</td>
#       <td>2.584431</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>1.674793</td>
#       <td>0.287895</td>
#       <td>-0.289040</td>
#       <td>-0.820070</td>
#       <td>0.735354</td>
#       <td>-0.119188</td>
#     </tr>
#     <tr>
#       <th>C</th>
#       <td>-0.854056</td>
#       <td>0.541482</td>
#       <td>-0.434537</td>
#       <td>0.641087</td>
#       <td>0.717406</td>
#       <td>2.043724</td>
#     </tr>
#     <tr>
#       <th>D</th>
#       <td>1.022752</td>
#       <td>-0.859061</td>
#       <td>-0.547957</td>
#       <td>0.154080</td>
#       <td>0.549194</td>
#       <td>-0.825224</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Sorting by its index

# %%
kdf.sort_index(ascending=False)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>5</th>
#       <td>2.584431</td>
#       <td>-0.119188</td>
#       <td>2.043724</td>
#       <td>-0.825224</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1.971336</td>
#       <td>0.735354</td>
#       <td>0.717406</td>
#       <td>0.549194</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1.478943</td>
#       <td>-0.820070</td>
#       <td>0.641087</td>
#       <td>0.154080</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>-0.195844</td>
#       <td>-0.289040</td>
#       <td>-0.434537</td>
#       <td>-0.547957</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.206535</td>
#       <td>0.287895</td>
#       <td>0.541482</td>
#       <td>-0.859061</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>-0.226162</td>
#       <td>1.674793</td>
#       <td>-0.854056</td>
#       <td>1.022752</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Sorting by value

# %%
kdf.sort_values(by='B')
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3</th>
#       <td>1.478943</td>
#       <td>-0.820070</td>
#       <td>0.641087</td>
#       <td>0.154080</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>-0.195844</td>
#       <td>-0.289040</td>
#       <td>-0.434537</td>
#       <td>-0.547957</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>2.584431</td>
#       <td>-0.119188</td>
#       <td>2.043724</td>
#       <td>-0.825224</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.206535</td>
#       <td>0.287895</td>
#       <td>0.541482</td>
#       <td>-0.859061</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1.971336</td>
#       <td>0.735354</td>
#       <td>0.717406</td>
#       <td>0.549194</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>-0.226162</td>
#       <td>1.674793</td>
#       <td>-0.854056</td>
#       <td>1.022752</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ## Missing Data
# Koalas primarily uses the value `np.nan` to represent missing data. It is by default not included in computations.

# %%
pdf1 = pdf.reindex(index=dates[0:4], columns=list(pdf.columns) + ['E'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
pdf1.loc[dates[0]:dates[1], 'E'] = 1
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
kdf1 = ks.from_pandas(pdf1)

kdf1
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#       <th>E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2013-01-01</th>
#       <td>-0.226162</td>
#       <td>1.674793</td>
#       <td>-0.854056</td>
#       <td>1.022752</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>2013-01-02</th>
#       <td>0.206535</td>
#       <td>0.287895</td>
#       <td>0.541482</td>
#       <td>-0.859061</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>2013-01-03</th>
#       <td>-0.195844</td>
#       <td>-0.289040</td>
#       <td>-0.434537</td>
#       <td>-0.547957</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2013-01-04</th>
#       <td>1.478943</td>
#       <td>-0.820070</td>
#       <td>0.641087</td>
#       <td>0.154080</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# To drop any rows that have missing data.

# %%
kdf1.dropna(how='any')
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#       <th>E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2013-01-01</th>
#       <td>-0.226162</td>
#       <td>1.674793</td>
#       <td>-0.854056</td>
#       <td>1.022752</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>2013-01-02</th>
#       <td>0.206535</td>
#       <td>0.287895</td>
#       <td>0.541482</td>
#       <td>-0.859061</td>
#       <td>1.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Filling missing data.

# %%
kdf1.fillna(value=5)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#       <th>E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2013-01-01</th>
#       <td>-0.226162</td>
#       <td>1.674793</td>
#       <td>-0.854056</td>
#       <td>1.022752</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>2013-01-02</th>
#       <td>0.206535</td>
#       <td>0.287895</td>
#       <td>0.541482</td>
#       <td>-0.859061</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>2013-01-03</th>
#       <td>-0.195844</td>
#       <td>-0.289040</td>
#       <td>-0.434537</td>
#       <td>-0.547957</td>
#       <td>5.0</td>
#     </tr>
#     <tr>
#       <th>2013-01-04</th>
#       <td>1.478943</td>
#       <td>-0.820070</td>
#       <td>0.641087</td>
#       <td>0.154080</td>
#       <td>5.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ## Operations

# %% [markdown]
# ### Stats
# Operations in general exclude missing data.
#
# Performing a descriptive statistic:

# %%
print(kdf.mean())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">A    0.969873
# B    0.244957
# C    0.442518
# D   -0.084369
# Name: 0, dtype: float64
# </div>

# %% [markdown]
# ### Spark Configurations
#
# Various configurations in PySpark could be applied internally in Koalas.
# For example, you can enable Arrow optimization to hugely speed up internal pandas conversion. See <a href="https://spark.apache.org/docs/latest/sql-pyspark-pandas-with-arrow.html">PySpark Usage Guide for Pandas with Apache Arrow</a>.

# %%
prev = spark.conf.get("spark.sql.execution.arrow.enabled")  # Keep its default value.
ks.set_option("compute.default_index_type", "distributed")  # Use default index prevent overhead.
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
spark.conf.set("spark.sql.execution.arrow.enabled", True)
# %timeit ks.range(300000).to_pandas()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">118 ms ± 7.84 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# </div>

# %%
spark.conf.set("spark.sql.execution.arrow.enabled", False)
# %timeit ks.range(300000).to_pandas()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">983 ms ± 31 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# </div>

# %%
ks.reset_option("compute.default_index_type")
spark.conf.set("spark.sql.execution.arrow.enabled", prev)  # Set its default value back.
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Grouping
# By “group by” we are referring to a process involving one or more of the following steps:
#
# - Splitting the data into groups based on some criteria
# - Applying a function to each group independently
# - Combining the results into a data structure

# %%
kdf = ks.DataFrame({'A': ['foo', 'bar', 'foo', 'bar',
                          'foo', 'bar', 'foo', 'foo'],
                    'B': ['one', 'one', 'two', 'three',
                          'two', 'two', 'one', 'three'],
                    'C': np.random.randn(8),
                    'D': np.random.randn(8)})

kdf
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>foo</td>
#       <td>one</td>
#       <td>-0.998764</td>
#       <td>-0.316316</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>bar</td>
#       <td>one</td>
#       <td>0.489795</td>
#       <td>-1.559307</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>foo</td>
#       <td>two</td>
#       <td>0.449214</td>
#       <td>-0.825489</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>bar</td>
#       <td>three</td>
#       <td>-0.129954</td>
#       <td>0.876669</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>foo</td>
#       <td>two</td>
#       <td>0.627043</td>
#       <td>-0.838689</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>bar</td>
#       <td>two</td>
#       <td>-0.933623</td>
#       <td>0.228107</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>foo</td>
#       <td>one</td>
#       <td>1.375377</td>
#       <td>-0.175813</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>foo</td>
#       <td>three</td>
#       <td>0.420416</td>
#       <td>0.089990</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Grouping and then applying the [sum()](https://koalas.readthedocs.io/en/latest/reference/api/databricks.koalas.groupby.GroupBy.sum.html#databricks.koalas.groupby.GroupBy.sum) function to the resulting groups.

# %%
kdf.groupby('A').sum()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#     <tr>
#       <th>A</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>bar</th>
#       <td>-0.573782</td>
#       <td>-0.454530</td>
#     </tr>
#     <tr>
#       <th>foo</th>
#       <td>1.873285</td>
#       <td>-2.066317</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Grouping by multiple columns forms a hierarchical index, and again we can apply the sum function.

# %%
kdf.groupby(['A', 'B']).sum()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#     <tr>
#       <th>A</th>
#       <th>B</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">foo</th>
#       <th>one</th>
#       <td>0.376612</td>
#       <td>-0.492129</td>
#     </tr>
#     <tr>
#       <th>two</th>
#       <td>1.076257</td>
#       <td>-1.664178</td>
#     </tr>
#     <tr>
#       <th>bar</th>
#       <th>three</th>
#       <td>-0.129954</td>
#       <td>0.876669</td>
#     </tr>
#     <tr>
#       <th>foo</th>
#       <th>three</th>
#       <td>0.420416</td>
#       <td>0.089990</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">bar</th>
#       <th>two</th>
#       <td>-0.933623</td>
#       <td>0.228107</td>
#     </tr>
#     <tr>
#       <th>one</th>
#       <td>0.489795</td>
#       <td>-1.559307</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ## Plotting
# See the <a href="https://koalas.readthedocs.io/en/latest/reference/frame.html#plotting">Plotting</a> docs.

# %%
from matplotlib import pyplot as plt
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# On a DataFrame, the <a href="https://koalas.readthedocs.io/en/latest/reference/api/databricks.koalas.frame.DataFrame.plot.html#databricks.koalas.frame.DataFrame.plot">plot()</a> method is a convenience to plot all of the columns with labels:

# %%
pdf = pd.DataFrame(np.random.randn(1000, 4),
                   columns=['A', 'B', 'C', 'D'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
kdf = ks.from_pandas(pdf)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
cumsum = kdf.cumsum()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(cumsum.plot.line())

# %% [markdown]
# ## Getting data in/out
# See the <a href="https://koalas.readthedocs.io/en/latest/reference/io.html">Input/Output
# </a> docs.

# %% [markdown]
# ### CSV
#
# CSV is straightforward and easy to use. See <a href="https://koalas.readthedocs.io/en/latest/reference/api/databricks.koalas.DataFrame.to_csv.html#databricks.koalas.DataFrame.to_csv">here</a> to write a CSV file and <a href="https://koalas.readthedocs.io/en/latest/reference/api/databricks.koalas.read_csv.html#databricks.koalas.read_csv">here</a> to read a CSV file.

# %%
kdf.to_csv('foo.csv')
ks.read_csv('foo.csv').head(10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.468022</td>
#       <td>-1.872823</td>
#       <td>0.595022</td>
#       <td>0.714824</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>-0.782861</td>
#       <td>0.025656</td>
#       <td>-0.402027</td>
#       <td>0.804350</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1.475614</td>
#       <td>-0.245947</td>
#       <td>0.763012</td>
#       <td>-0.597314</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.501749</td>
#       <td>-1.881050</td>
#       <td>0.926464</td>
#       <td>1.104360</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.301102</td>
#       <td>-1.571696</td>
#       <td>-0.089858</td>
#       <td>-0.050796</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>-0.368900</td>
#       <td>1.404831</td>
#       <td>0.576704</td>
#       <td>-0.824325</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>0.011766</td>
#       <td>-0.858733</td>
#       <td>-0.063170</td>
#       <td>1.133711</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>0.149376</td>
#       <td>-1.004977</td>
#       <td>0.823343</td>
#       <td>0.085745</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>-0.539245</td>
#       <td>-0.366833</td>
#       <td>0.073860</td>
#       <td>0.097723</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>-0.037103</td>
#       <td>1.992246</td>
#       <td>-2.076988</td>
#       <td>0.009194</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### Parquet
#
# Parquet is an efficient and compact file format to read and write faster. See <a href="https://koalas.readthedocs.io/en/latest/reference/api/databricks.koalas.DataFrame.to_parquet.html#databricks.koalas.DataFrame.to_parquet">here</a> to write a Parquet file and <a href="https://koalas.readthedocs.io/en/latest/reference/api/databricks.koalas.read_parquet.html#databricks.koalas.read_parquet">here</a> to read a Parquet file.

# %%
kdf.to_parquet('bar.parquet')
ks.read_parquet('bar.parquet').head(10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1.240890</td>
#       <td>-1.253864</td>
#       <td>0.398638</td>
#       <td>-0.945324</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.205416</td>
#       <td>-0.352338</td>
#       <td>-0.001231</td>
#       <td>0.337425</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>-1.246664</td>
#       <td>0.636766</td>
#       <td>1.121499</td>
#       <td>-0.004852</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>-0.642459</td>
#       <td>-0.053354</td>
#       <td>-1.599536</td>
#       <td>-0.942180</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>-0.120679</td>
#       <td>0.318601</td>
#       <td>0.638337</td>
#       <td>-1.192724</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>-1.695289</td>
#       <td>-1.626982</td>
#       <td>-0.235787</td>
#       <td>1.598541</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>-0.247538</td>
#       <td>-0.676712</td>
#       <td>0.106915</td>
#       <td>-1.044883</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>-1.081124</td>
#       <td>-0.455626</td>
#       <td>0.979824</td>
#       <td>1.443102</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>-1.012571</td>
#       <td>-1.015224</td>
#       <td>0.135464</td>
#       <td>1.006207</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>0.672080</td>
#       <td>-0.130600</td>
#       <td>0.131746</td>
#       <td>0.020615</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### Spark IO
#
# In addition, Koalas fully support Spark's various datasources such as ORC and an external datasource.  See <a href="https://koalas.readthedocs.io/en/latest/reference/api/databricks.koalas.DataFrame.to_spark_io.html#databricks.koalas.DataFrame.to_spark_io">here</a> to write it to the specified datasource and <a href="https://koalas.readthedocs.io/en/latest/reference/api/databricks.koalas.read_spark_io.html#databricks.koalas.read_spark_io">here</a> to read it from the datasource.

# %%
kdf.to_spark_io('zoo.orc', format="orc")
ks.read_spark_io('zoo.orc', format="orc").head(10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1.240890</td>
#       <td>-1.253864</td>
#       <td>0.398638</td>
#       <td>-0.945324</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.205416</td>
#       <td>-0.352338</td>
#       <td>-0.001231</td>
#       <td>0.337425</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>-1.246664</td>
#       <td>0.636766</td>
#       <td>1.121499</td>
#       <td>-0.004852</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>-0.642459</td>
#       <td>-0.053354</td>
#       <td>-1.599536</td>
#       <td>-0.942180</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>-0.120679</td>
#       <td>0.318601</td>
#       <td>0.638337</td>
#       <td>-1.192724</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>-1.695289</td>
#       <td>-1.626982</td>
#       <td>-0.235787</td>
#       <td>1.598541</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>-0.247538</td>
#       <td>-0.676712</td>
#       <td>0.106915</td>
#       <td>-1.044883</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>-1.081124</td>
#       <td>-0.455626</td>
#       <td>0.979824</td>
#       <td>1.443102</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>-1.012571</td>
#       <td>-1.015224</td>
#       <td>0.135464</td>
#       <td>1.006207</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>0.672080</td>
#       <td>-0.130600</td>
#       <td>0.131746</td>
#       <td>0.020615</td>
#     </tr>
#   </tbody>
# </table>
# </div>
